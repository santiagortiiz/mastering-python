# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# when there are no slots for new elements, the list is copied to a new memory block and the array is allocated with more free slots according to a formula

# %% [markdown]
# ![image.png](attachment:image.png)
