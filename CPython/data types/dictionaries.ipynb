# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In case of a collision in the hash, python looks for the next free index to allocate the new key-value pair

# %% [markdown]
# ![image.png](attachment:image.png)
