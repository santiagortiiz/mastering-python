# %% [markdown]
# # Custom Exceptions

# %%
class MyException(Exception):

    def __init__(self, message):
        self.message = message

# %%
raise MyException('Custom Message')
# Out:
# ---------------------------------------------------------------------------
# MyException                               Traceback (most recent call last)
# c:\Users\Santiago_Ortiz\mastering-python\Concepts\Exceptions.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Santiago_Ortiz/mastering-python/Concepts/Exceptions.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> raise MyException('Custom Message')
#
# MyException: Custom Message

# %%
try:
    result = 1/0
except ZeroDivisionError:
    print("invalid operation")
# Out:
# invalid operation

# %%
try:
    result = 10/2
except ZeroDivisionError:
    print("invalid operation")
else:
    print(f"valid operation, result: {result}")
# Out:
# valid operation, result: 5.0

# %%
try:
    result = 10/0
except ZeroDivisionError:
    print("invalid operation")
finally:
    print('Always happen')
# Out:
# invalid operation
# Always happen

# %%
try:
    result = 10/1
except ZeroDivisionError:
    print("invalid operation")
else:
    print('haha')
finally:
    print('Always happen')
# Out:
# haha
# Always happen
