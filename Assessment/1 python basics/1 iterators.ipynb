# %% [markdown]
# # [Iterators](https://docs.python.org/3/library/functions.html#iter)
# ![image.png](attachment:image.png)

# %% [markdown]
# iterable: An object capable of returning its members one at a time. Sequences / Non-sequences / Custom objects that implements sequence semantic (__iter__ or __getitem__)
# iterator: An object representing a stream of data, must support iter and next methods (iterator protocol).

# %%
mylist = [1, 2, 3]
for i in iter(mylist):
    print(i)
# Out:
# 1
# 2
# 3

# %%
class MyIterator:
    def __iter__(self):
        self.index = 0
        return self

    def __next__(self):
        if self.index < 5:
            result = self.index
            self.index += 1
            return result
        else:
            raise StopIteration

my_iterator = MyIterator()

# Obtener elementos uno por uno
for item in my_iterator:
    print(item)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = iter(my_iterator)

# %%
next(i)
# Out:
# 0

# %%
next(i)
# Out:
# 1

# %%
for i in iter(mylist, 2):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Santiago_Ortiz\mastering-python\Assessment\python_basics.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Santiago_Ortiz/mastering-python/Assessment/python_basics.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> for i in iter(mylist, 2):
#       <a href='vscode-notebook-cell:/c%3A/Users/Santiago_Ortiz/mastering-python/Assessment/python_basics.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     print(i)
#
# TypeError: iter(v, w): v must be callable

# %%
# Second form of iter is useful to build a block-reader
from functools import partial
with open('mydata.db', 'rb') as f:
    for block in iter(partial(f.read, 64), b''):
        process_block(block)

# %% [markdown]
# # Generators

# %% [markdown]
# They are normally created by iterating over a function that yields values

# %%
# Usando comprehensions para crear una tupla
mi_tupla = tuple(x for x in range(5))
print(mi_tupla, type(mi_tupla))
# Out:
# (0, 1, 2, 3, 4) <class 'tuple'>

# %%
# Usando comprehensions para crear una tupla
generator = (x for x in range(5))
print(generator)
# Out:
# <generator object <genexpr> at 0x000001B41A389A40>
