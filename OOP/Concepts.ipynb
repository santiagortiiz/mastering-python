# %% [markdown]
# ![image.png](attachment:image.png)
# [Ref](https://www.quora.com/Why-is-Python-an-object-oriented-language)

# %%
class A:
    
    def __init__(self, a, b):
        self._private = a
        self.__protected = b

# %%
a = A('private attr', 'protected attr')

# %%
a._private = 'private updated'
a._private
# Out:
# 'private updated'

# %%
a.__protected
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SANTIA~1\AppData\Local\Temp/ipykernel_19044/2418999417.py in <module>
# ----> 1 a.__protected
#
# AttributeError: 'A' object has no attribute '__protected'
